# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sweetviz as sv
import category_encoders as ce
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.decomposition import PCA
from pandas_profiling import ProfileReport
from sklearn.preprocessing import StandardScaler
from feature_engine.encoding import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
heart_dis_pred = pd.read_csv("heart_cleaned_eda.csv")

# %%
encoder = OneHotEncoder( top_categories=1, variables=['HeartDisease','Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking', 'Sex', 'Diabetic', 'KidneyDisease', 'SkinCancer', 'PhysicalActivity', 'Asthma'], drop_last=False)
encoder.fit(heart_dis_pred)
heart_dis_pred = encoder.transform(heart_dis_pred)

# %%
heart_dis_pred.head(5)
# Out:
#    Unnamed: 0    BMI  PhysicalHealth  MentalHealth  AgeCategory   Race  \
# 0           0  16.60               3            30        55-59  White
# 1           1  20.34               0             0  80 or older  White
# 2           2  26.58              20            30        65-69  White
# 3           3  24.21               0             0        75-79  White
# 4           4  23.71              28             0        40-44  White
#
#    GenHealth  SleepTime  HeartDisease_No  Smoking_No  AlcoholDrinking_No  \
# 0  Very good          5                1           0                   1
# 1  Very good          7                1           1                   1
# 2       Fair          8                1           0                   1
# 3       Good          6                1           1                   1
# 4  Very good          8                1           1                   1
#
#    Stroke_No  DiffWalking_No  Sex_Female  Diabetic_No  KidneyDisease_No  \
# ...

# %%
heart_dis_pred.shape
# Out:
# (319795, 19)

# %%
encoder = ce.BinaryEncoder(cols=['Race', 'GenHealth', 'AgeCategory'])
df_binary = encoder.fit_transform(heart_dis_pred)
df_binary.head()
# Out:
#    Unnamed: 0    BMI  PhysicalHealth  MentalHealth  AgeCategory_0  \
# 0           0  16.60               3            30              0
# 1           1  20.34               0             0              0
# 2           2  26.58              20            30              0
# 3           3  24.21               0             0              0
# 4           4  23.71              28             0              0
#
#    AgeCategory_1  AgeCategory_2  AgeCategory_3  Race_0  Race_1  Race_2  \
# 0              0              0              1       0       0       1
# 1              0              1              0       0       0       1
# 2              0              1              1       0       0       1
# 3              1              0              0       0       0       1
# 4              1              0              1       0       0       1
#
#    GenHealth_0  GenHealth_1  GenHealth_2  SleepTime  HeartDisease_No  \
# ...

# %%
df_binary.shape
# Out:
# (319795, 26)

# %%
df_binary.to_csv("heart_cleaned_encoded.csv")
